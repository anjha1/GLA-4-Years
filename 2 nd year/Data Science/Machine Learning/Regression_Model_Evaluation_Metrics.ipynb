# %% [markdown]
# <a href="https://colab.research.google.com/github/anjha1/GLA-4-Years/blob/main/2%20nd%20year/Data%20Science/Machine%20Learning/Regression_Model_Evaluation_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import mean_absolute_error

# %%
actual=[2,3,5,5,9]
predicted=[3,3,8,7,6]

# %%
mea=mean_absolute_error(actual,predicted)
mea
# Out:
# 1.8

# %%
from sklearn.metrics import mean_squared_error

# %%
mae=mean_squared_error(actual,predicted)
mae
# Out:
# 4.6

# %%
import numpy as np

# %%
mse=np.sqrt(mae)
mse
# Out:
# 2.1447610589527217

# %%
mse1=(mae)**(0.5)
mse1
# Out:
# 2.1447610589527217

# %%
from sklearn.metrics import r2_score

# %%
r2_score=r2_score(actual,predicted)
r2_score
# Out:
# 0.20138888888888895

# %% [markdown]
# ![image.png](data:image/png;base64,...)
